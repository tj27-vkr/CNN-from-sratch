# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
# %matplotlib inline
import layerdefinition as layer

# %%
image = cv2.imread("avacado.jpg")
image = cv2.resize(image, (64, 64) , interpolation = cv2.INTER_CUBIC)

plt.imshow(image)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
np.random.seed(1)
weight = np.random.randn(3, 3)
bias = np.random.rand()  
print("selected kernel {} and bias {}".format(kernel,bias))

conv_image = layer.conv2D(image, weight, bias)

plt.imshow(conv_image)
plt.show
# Out:
# selected kernel [[ 0.28558733  0.88514116 -0.75439794]
#  [ 1.25286816  0.51292982 -0.29809284]
#  [ 0.48851815 -0.07557171  1.13162939]] and bias 0.027387593197926163
# <function matplotlib.pyplot.show>
